# %% [markdown]
# # Creating a Simple Agent with Tracing

# %%
import dotenv
import os

from openai import OpenAI

dotenv.load_dotenv()

if not os.environ.get("OPENAI_API_KEY"):
    print(
        """Error: OPENAI_API_KEY environment variable not set. Please copy the .env.template file as .env and fill it in.
    
    You can execute these commands in the terminal to get started:
    cp .env.template .env
    code .env
    """
    )

# Test OpenAI Access
print(
    OpenAI()
    .responses.create(
        model=os.environ["OPENAI_DEFAULT_MODEL"], input="Say: We are up and running!"
    )
    .output_text
)
# Out:
# We are up and running!

# %%
from agents import Agent, Runner, trace
from openai.types.responses import ResponseTextDeltaEvent

# %% [markdown]
# Create a simple Nutrition Assistant Agent

# %%
nutrition_agent = Agent (
    name="Nutrition Assistant",
    instructions="""You are a helpful assistant giving out nutrition advice. You give concise answers."""
)

# %% [markdown]
# Let's execute the Agent:

# %%
with trace("Simple Nutrition Agent"):
    result = await Runner.run(nutrition_agent, "How healthy are bananas?")

print(result)
# Out:
# RunResult:
# - Last agent: Agent(name="Nutrition Assistant", ...)
# - Final output (str):
#     Bananas are a healthy, convenient fruit.
#
#     Key points:
#     - Nutrients: good source of potassium (supports blood pressure/heart function), vitamin B6, vitamin C, and dietary fiber.
#     - Energy: about 90–105 kcal per medium banana; natural sugars provide quick energy.
#     - Fiber: roughly 3–4 g per medium banana aids digestion.
#     - Glycemic index: moderate; ripe bananas may be sweeter and slightly higher GI than unripe.
#     - Uses: great on-the-go, pair with protein (e.g., peanut butter) to improve satiety.
#
#     Cautions:
#     - if you have kidney disease or need to limit potassium, monitor intake.
#     - portion control if watching calories or sugars.
#
#     Overall: a healthy, versatile fruit to include in a balanced diet.
# - 2 new item(s)
# - 1 raw response(s)
# - 0 input guardrail result(s)
# - 0 output guardrail result(s)
# (See `RunResult` for more details)

# %% [markdown]
# Streaming the answer to the screen, token by token

# %%
response_stream = Runner.run_streamed(nutrition_agent, "How healthy are bananas?")

async for event in response_stream.stream_events():
    if event.type == "raw_response_event" and isinstance(
        event.data, ResponseTextDeltaEvent
    ):
        print(event.data.delta, end="", flush=True)
# Out:
# Overall, bananas are a healthy, convenient fruit.
#
# Key benefits:
# - Good source of potassium, vitamin B6, vitamin C, and dietary fiber.
# - Quick energy from natural sugars; fiber helps steady blood sugar.
# - May aid digestion (resistant starch in less ripe bananas).
#
# Considerations:
# - Higher sugar content as they ripen; portion size matters if watching sugar/calories.
# - Unripe bananas have more resistant starch and lower sugar.
# - People with kidney disease or on potassium-restricted diets should monitor intake.
#
# A typical banana (1 medium) fits well in most balanced diets.

# %% [markdown]
# _Good Job!_
